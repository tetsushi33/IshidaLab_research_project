# %%
# !pwd
import pandas as pd
import matplotlib.pyplot as plt
import os
# Out:
# /home/takanishi

# %% [markdown]
# ## pocket_analysis_resultを一つのファイルに結合する
# まとめ方
# - apo_name, apo_chain, pocket_id　のセットで重複が内容にひとつだけ選択する
# - その際にpocket_rmsdが最も大きい行を採用する
# - 他の行は、apo_pocket_missing_percentage,holo_loop_perの二つは一旦まとめには含めず、無視する

# %%
# input
pocket_analysis_results = "IshidaLab_research_project/dataset_preprocess/output_csv_files/phase_06/ver_8"
# output
output_dir = "IshidaLab_research_project/dataset_preprocess/output_csv_files/phase_07/ver_3"
output_csv = os.path.join(output_dir, "max_pocket_rmsd_results1.csv")

def process(start_id, end_id):
    # read data
    pocket_analysis_results_file = f"{pocket_analysis_results}/pocket_analysis_results_{start_id}_to_{end_id}.csv"
    df = pd.read_csv(pocket_analysis_results_file, delimiter=',')

    # 抽出したい列を指定
    columns_to_extract = ['apo_name', 'apo_chain', 'holo_name', 'holo_chain', 'pocket_id', 'pocket_rmsd', 'pocket_com', 'protein_id', 'ligand', 'ligand_atom_count']
    df = df[columns_to_extract]
    print("df : ")
    print(df.head(4))
    
    # グループ化して処理
    grouped = df.groupby(['apo_name', 'apo_chain', 'pocket_id'])
    # 各グループのうち、pocket_rmsd の値が最大の行を抽出
    result = df.loc[grouped['pocket_rmsd'].idxmax()].reset_index(drop=True)
    print("result : ")
    print(result)
    # インデックスをリセットして元の列を復元
    result = result.reset_index(drop=True)
    # pocket_rmsd を max_pocket_rmsd に名前変更
    result = result.rename(columns={'pocket_rmsd': 'max_pocket_rmsd'})
    # 列の順序を指定
    result = result[['apo_name', 'apo_chain', 'holo_name', 'holo_chain', 'pocket_id', 'max_pocket_rmsd', 'pocket_com', 'protein_id', 'ligand', 'ligand_atom_count']]
    
    # 結果の確認
    print(result)
    result.to_csv(output_csv, mode='a', index=False, header=False)

# %%
process(21, 100)
# Out:
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     1C5M         D      2vwo          A          1     2.586221
# 1     1C5M         D      4y79          A          1     0.812076
# 2     1C5M         D      1z6e          A          1     4.031338
# 3     1C5M         D      2p16          A          1     3.305785
#
#                                           pocket_com  protein_id ligand  \
# 0  [-0.5766737066163607, -7.033213047893501, 8.64...          21    LZG
# 1  [-0.5766737066163607, -7.033213047893501, 8.64...          21    4O6
# 2  [-0.5766737066163607, -7.033213047893501, 8.64...          21    IK8
# 3  [-0.5766737066163607, -7.033213047893501, 8.64...          21    GG2
#
#    ligand_atom_count
# 0                 33
# 1                 29
# 2                 38
# 3                 34
# result :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     1C5M         D      1g2l          A          1     4.505581
# 1     1HCG         A      1g2l          A          1     4.475010
# 2     5ZA4         A      5z99          A          1     3.304524
# 3     5ZA4         A      5yyb          A          2     3.419927
# 4     7TPP         B      1xka          C          1     8.764378
#
#                                           pocket_com  protein_id ligand  \
# 0  [-0.5766737066163607, -7.033213047893501, 8.64...          21    T87
# 1  [-3.9557783833050517, -10.998595155710381, -2....          22    T87
# 2  [-7.1656364320919215, -5.210598451708326, -8.4...          23    SLB
# 3  [-3.9257919187764174, -5.5205611450071554, 10....          23    NGE
# 4  [5.513285182072566, -10.081479723025591, 3.909...          21    4PP
#
#    ligand_atom_count
# 0                 39
# 1                 39
# 2                 39
# 3                 40
# 4                 29
#   apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0     1C5M         D      1g2l          A          1         4.505581
# 1     1HCG         A      1g2l          A          1         4.475010
# 2     5ZA4         A      5z99          A          1         3.304524
# 3     5ZA4         A      5yyb          A          2         3.419927
# 4     7TPP         B      1xka          C          1         8.764378
#
#                                           pocket_com  protein_id ligand  \
# 0  [-0.5766737066163607, -7.033213047893501, 8.64...          21    T87
# 1  [-3.9557783833050517, -10.998595155710381, -2....          22    T87
# 2  [-7.1656364320919215, -5.210598451708326, -8.4...          23    SLB
# 3  [-3.9257919187764174, -5.5205611450071554, 10....          23    NGE
# 4  [5.513285182072566, -10.081479723025591, 3.909...          21    4PP
#
#    ligand_atom_count
# 0                 39
# 1                 39
# 2                 39
# 3                 40
# 4                 29

# %%
for i in range(20):
    start_id = (i+1) * 100 + 1
    end_id = start_id + 99
    if end_id > 2068:
        end_id = 2068
    #print(f"start_id: {start_id}, end_id: {end_id}")
    process(start_id, end_id)
# Out:
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     6X32         C      6o5g          A          1     3.213805
# 1     6X32         C      6eeb          A          1     2.693449
# 2     6X32         C      2llq          A          1     3.273849
# 3     6X32         C      2mg5          A          1    16.312613
#
#                                           pocket_com  protein_id ligand  \
# 0  [-0.3114616974540379, 0.16574341317881708, -0....         101    LMJ
# 1  [-0.3114616974540379, 0.16574341317881708, -0....         101    J6P
# 2  [-0.3114616974540379, 0.16574341317881708, -0....         101    NaN
# 3  [-0.3114616974540379, 0.16574341317881708, -0....         101    TPO
#
#    ligand_atom_count
# 0                 27
# 1                 27
# 2                  0
# 3                 15
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       102L         A      3run          A          3     0.244533
# 1       107L         A      3run          A          3     0.279195
# 2       108L         A      3run          A          3     0.230535
# 3       109L         A      3run          A          3     0.238453
# 4       110L         A      3run          A          3     0.226932
# ..       ...       ...       ...        ...        ...          ...
# 293     8C5G         A      5j1x          A          1     1.397545
# 294     8IN0         A      3wdz          A          1     0.975041
# 295     8R0E         A      5b6c          A          4     2.710330
# 296     8RS9         A      3hu3          A          4     2.338328
# 297     8WZD         A      5km2          A          1     0.899096
#
#                                             pocket_com  protein_id ligand  \
# 0    [8.337709276863698, -4.206374350558506, 1.6357...         124    OMZ
# 1    [8.33654669429479, -4.119289516063219, 1.80432...         124    OMZ
# 2    [8.326352751656865, -4.179361488042253, 1.6317...         124    OMZ
# 3    [8.323322553313181, -4.072632896766234, 1.7284...         124    OMZ
# 4    [8.32487830687105, -4.1330074460318915, 1.5820...         124    OMZ
# ..                                                 ...         ...    ...
# 293  [-14.141870382826339, -21.483723968629413, -13...         129    AR5
# 294  [1.118261931924259, -12.948551447251264, 8.866...         132    SEP
# 295  [-13.805773138455605, 5.0947662423190465, 46.5...         109    NaN
# 296  [1.2598238594924347, 6.07574037962322, -9.2807...         109    AGS
# 297  [1.805616263187293, 3.9480312231815224, 6.3347...         107    C5P
#
#      ligand_atom_count
# 0                   14
# 1                   14
# 2                   14
# 3                   14
# 4                   14
# ..                 ...
# 293                 19
# 294                 10
# 295                  0
# 296                 31
# 297                 21
#
# [298 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       102L         A      3run          A          3         0.244533
# 1       107L         A      3run          A          3         0.279195
# 2       108L         A      3run          A          3         0.230535
# 3       109L         A      3run          A          3         0.238453
# 4       110L         A      3run          A          3         0.226932
# ..       ...       ...       ...        ...        ...              ...
# 293     8C5G         A      5j1x          A          1         1.397545
# 294     8IN0         A      3wdz          A          1         0.975041
# 295     8R0E         A      5b6c          A          4         2.710330
# 296     8RS9         A      3hu3          A          4         2.338328
# 297     8WZD         A      5km2          A          1         0.899096
#
#                                             pocket_com  protein_id ligand  \
# 0    [8.337709276863698, -4.206374350558506, 1.6357...         124    OMZ
# 1    [8.33654669429479, -4.119289516063219, 1.80432...         124    OMZ
# 2    [8.326352751656865, -4.179361488042253, 1.6317...         124    OMZ
# 3    [8.323322553313181, -4.072632896766234, 1.7284...         124    OMZ
# 4    [8.32487830687105, -4.1330074460318915, 1.5820...         124    OMZ
# ..                                                 ...         ...    ...
# 293  [-14.141870382826339, -21.483723968629413, -13...         129    AR5
# 294  [1.118261931924259, -12.948551447251264, 8.866...         132    SEP
# 295  [-13.805773138455605, 5.0947662423190465, 46.5...         109    NaN
# 296  [1.2598238594924347, 6.07574037962322, -9.2807...         109    AGS
# 297  [1.805616263187293, 3.9480312231815224, 6.3347...         107    C5P
#
#      ligand_atom_count
# 0                   14
# 1                   14
# 2                   14
# 3                   14
# 4                   14
# ..                 ...
# 293                 19
# 294                 10
# 295                  0
# 296                 31
# 297                 21
#
# [298 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     2V5D         A      2wb5          A          1     1.521255
# 1     2V5D         A      2j62          B          2     2.378906
# 2     2V5D         A      2cbj          A          1     1.440848
# 3     2V5D         A      2xpk          A          1     0.424450
#
#                                           pocket_com  protein_id ligand  \
# 0  [3.9916801497906067, -12.711271101412391, 2.34...         201    VGB
# 1  [-15.829273790121078, 21.132341876626015, 19.1...         201    GSZ
# 2  [3.9916801497906067, -12.711271101412391, 2.34...         201    OAN
# 3  [3.9916801497906067, -12.711271101412391, 2.34...         201    Z0M
#
#    ligand_atom_count
# 0                 26
# 1                 27
# 2                 25
# 3                 27
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       133L         A      5lsh          A          1     0.848883
# 1       134L         A      5lsh          A          1     0.851666
# 2       1A3H         A      1h5v          A          1     1.626855
# 3       1A3Y         A      1dzj          A          1     0.829605
# 4       1AG1         O      1iig          B          1     3.940421
# ..       ...       ...       ...        ...        ...          ...
# 437     8ESA         A      4mnq          A          1     1.453204
# 438     8ESB         A      4mnq          A          1     1.422124
# 439     8OK1         A      6e22          A          2     8.432773
# 440     8SJ3         A      5ujo          A          2     0.711216
# 441     8X3S         A      6dai          A          2          inf
#
#                                             pocket_com  protein_id ligand  \
# 0    [0.6496929898157389, -4.968630194290305, 6.057...         246    TVG
# 1    [-0.1610053878592847, -4.856737722797454, 6.20...         246    TVG
# 2    [3.309534379736482, 1.5455598379911308, 9.8646...         257    MA3
# 3    [-2.3027988407571436, 0.7503815456972284, 1.48...         256    SES
# 4    [1.096791655222575, 0.4670395851135254, 5.8304...         207    3PP
# ..                                                 ...         ...    ...
# 437  [14.533182923222931, 0.5118255167499954, -0.28...         300    GOL
# 438  [14.57763150712134, -1.1134763995246708, 0.100...         300    GOL
# 439  [6.400327002865144, 5.077902881578467, 1.95087...         249    HLS
# 440  [-5.379593086242676, -7.6144585609436035, -3.8...         255    8CY
# 441  [-0.4923640126767366, -1.8911785353784976, 6.3...         249    G2V
#
#      ligand_atom_count
# 0                   15
# 1                   15
# 2                   13
# 3                   13
# 4                    9
# ..                 ...
# 437                  6
# 438                  6
# 439                 28
# 440                 31
# 441                 18
#
# [442 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       133L         A      5lsh          A          1         0.848883
# 1       134L         A      5lsh          A          1         0.851666
# 2       1A3H         A      1h5v          A          1         1.626855
# 3       1A3Y         A      1dzj          A          1         0.829605
# 4       1AG1         O      1iig          B          1         3.940421
# ..       ...       ...       ...        ...        ...              ...
# 437     8ESA         A      4mnq          A          1         1.453204
# 438     8ESB         A      4mnq          A          1         1.422124
# 439     8OK1         A      6e22          A          2         8.432773
# 440     8SJ3         A      5ujo          A          2         0.711216
# 441     8X3S         A      6dai          A          2              inf
#
#                                             pocket_com  protein_id ligand  \
# 0    [0.6496929898157389, -4.968630194290305, 6.057...         246    TVG
# 1    [-0.1610053878592847, -4.856737722797454, 6.20...         246    TVG
# 2    [3.309534379736482, 1.5455598379911308, 9.8646...         257    MA3
# 3    [-2.3027988407571436, 0.7503815456972284, 1.48...         256    SES
# 4    [1.096791655222575, 0.4670395851135254, 5.8304...         207    3PP
# ..                                                 ...         ...    ...
# 437  [14.533182923222931, 0.5118255167499954, -0.28...         300    GOL
# 438  [14.57763150712134, -1.1134763995246708, 0.100...         300    GOL
# 439  [6.400327002865144, 5.077902881578467, 1.95087...         249    HLS
# 440  [-5.379593086242676, -7.6144585609436035, -3.8...         255    8CY
# 441  [-0.4923640126767366, -1.8911785353784976, 6.3...         249    G2V
#
#      ligand_atom_count
# 0                   15
# 1                   15
# 2                   13
# 3                   13
# 4                    9
# ..                 ...
# 437                  6
# 438                  6
# 439                 28
# 440                 31
# 441                 18
#
# [442 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     6APN         A      6d78          A          1     5.519177
# 1     6APN         A      3qfd          A          1     2.146713
# 2     6APN         A      5isz          A          1     2.348513
# 3     6APN         A      2x4s          A          1     2.378033
#
#                                           pocket_com  protein_id ligand  \
# 0  [1.0760295641904623, -13.921047499827568, 8.50...         301    NaN
# 1  [1.0760295641904623, -13.921047499827568, 8.50...         301    GOL
# 2  [1.0760295641904623, -13.921047499827568, 8.50...         301    GOL
# 3  [1.0760295641904623, -13.921047499827568, 8.50...         301    MES
#
#    ligand_atom_count
# 0                  0
# 1                  6
# 2                 14
# 3                 12
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A2W         A      1afk          A          1    17.649860
# 1       1A5Q         A      1o0o          A          1     1.377485
# 2       1ALB         A      3hk1          A          1     1.398280
# 3       1AMP         A      3b3c          A          1     0.660228
# 4       1AMP         A      3b3w          A          2     0.313430
# ..       ...       ...       ...        ...        ...          ...
# 223     8Q7Y         A      3t0b          D          2     1.518559
# 224     8Q7Y         A      3vd7          D          3     1.147296
# 225     8SNL         A      2oi0          A          1     1.405236
# 226     8SNL         A      2i47          D          2     0.682426
# 227     9ATC         A      2h3e          C          1     3.178493
#
#                                             pocket_com  protein_id ligand  \
# 0    [-0.8403015652616758, 1.6742615640808294, -1.0...         310    PAP
# 1    [0.3922123783707066, -2.482938947780792, 1.985...         310    A2P
# 2    [1.789116213626897, 2.6177447881680913, 3.4443...         336    B64
# 3    [-6.248199318394517, -2.2872044516332224, 11.6...         383    PLU
# 4    [6.1642891136375635, -5.352943758706789, 11.60...         383    LEU
# ..                                                 ...         ...    ...
# 223  [-6.8573356628417965, 9.741426849365235, -5.67...         340    IPT
# 224  [-19.77719963921441, 6.757963392469618, -15.09...         340    GTZ
# 225  [-9.620393864677759, -20.621075035658198, 13.8...         398    283
# 226  [17.633229573567707, -30.957382202148438, 4.10...         398    KGY
# 227  [-1.7626061750494915, -9.59833804420803, 8.441...         355    6PR
#
#      ligand_atom_count
# 0                   31
# 1                   27
# 2                   22
# 3                   10
# 4                    9
# ..                 ...
# 223                 15
# 224                 14
# 225                 20
# 226                 35
# 227                 16
#
# [228 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A2W         A      1afk          A          1        17.649860
# 1       1A5Q         A      1o0o          A          1         1.377485
# 2       1ALB         A      3hk1          A          1         1.398280
# 3       1AMP         A      3b3c          A          1         0.660228
# 4       1AMP         A      3b3w          A          2         0.313430
# ..       ...       ...       ...        ...        ...              ...
# 223     8Q7Y         A      3t0b          D          2         1.518559
# 224     8Q7Y         A      3vd7          D          3         1.147296
# 225     8SNL         A      2oi0          A          1         1.405236
# 226     8SNL         A      2i47          D          2         0.682426
# 227     9ATC         A      2h3e          C          1         3.178493
#
#                                             pocket_com  protein_id ligand  \
# 0    [-0.8403015652616758, 1.6742615640808294, -1.0...         310    PAP
# 1    [0.3922123783707066, -2.482938947780792, 1.985...         310    A2P
# 2    [1.789116213626897, 2.6177447881680913, 3.4443...         336    B64
# 3    [-6.248199318394517, -2.2872044516332224, 11.6...         383    PLU
# 4    [6.1642891136375635, -5.352943758706789, 11.60...         383    LEU
# ..                                                 ...         ...    ...
# 223  [-6.8573356628417965, 9.741426849365235, -5.67...         340    IPT
# 224  [-19.77719963921441, 6.757963392469618, -15.09...         340    GTZ
# 225  [-9.620393864677759, -20.621075035658198, 13.8...         398    283
# 226  [17.633229573567707, -30.957382202148438, 4.10...         398    KGY
# 227  [-1.7626061750494915, -9.59833804420803, 8.441...         355    6PR
#
#      ligand_atom_count
# 0                   31
# 1                   27
# 2                   22
# 3                   10
# 4                    9
# ..                 ...
# 223                 15
# 224                 14
# 225                 20
# 226                 35
# 227                 16
#
# [228 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     4HRI         A      4ynl          A          1     0.916327
# 1     1MAT         A      1yvm          A          1     0.732785
# 2     1MAT         A      4pnc          A          1     0.577910
# 3     1MAT         A      2evo          B          1     0.678787
#
#                                           pocket_com  protein_id ligand  \
# 0  [8.069333883432241, -5.806300811278514, 27.289...         401    NaN
# 1  [-9.987391722436044, 2.9875414081648284, 2.534...         402    TMG
# 2  [-9.987391722436044, 2.9875414081648284, 2.534...         402    7NP
# 3  [-9.987391722436044, 2.9875414081648284, 2.534...         402    CT0
#
#    ligand_atom_count
# 0                  0
# 1                 14
# 2                 14
# 3                 16
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1B7X         B      3po1          B          1     6.361672
# 1       1C2B         A      1q83          A          1     0.907920
# 2       1C2B         A      5ehn          A          2     1.080483
# 3       1C2O         A      5ehn          A          1     1.080454
# 4       1C69         A      223l          A          2     0.420170
# ..       ...       ...       ...        ...        ...          ...
# 199     7X6S         A      5t2t          A          1     2.650229
# 200     7XF3         A      1xr9          A          1     0.853395
# 201     7YER         B      4ibe          A          1     1.469493
# 202     8PEA         A      5qap          B          1     3.203113
# 203     8PEA         A      5fas          A          2     3.075023
#
#                                             pocket_com  protein_id ligand  \
# 0    [-1.179043956920861, 3.6813078413359475, -4.61...         463    MKY
# 1    [8.411259284944135, 6.42240844842599, -1.09772...         445    TZ5
# 2    [10.875006421726553, 0.966960542765095, 13.718...         445    5NZ
# 3    [-4.17155269641972, 15.92296933888191, -6.0388...         445    5NZ
# 4    [-4.765451171875, -3.536183225631714, -14.4452...         443    BNZ
# ..                                                 ...         ...    ...
# 199  [12.149139881134033, 32.49655342102051, -18.84...         419    0N8
# 200  [-9.368043024658721, -0.3903163542579475, 11.4...         450    GOL
# 201  [-8.778923882378471, 0.5329759385850694, -20.7...         480    11Y
# 202  [-4.29671223039572, -11.24640649453753, 11.579...         447    AV7
# 203  [-10.900771909146696, -2.8350691305624474, -1....         447    5VR
#
#      ligand_atom_count
# 0                   20
# 1                   50
# 2                   49
# 3                   49
# 4                    6
# ..                 ...
# 199                 52
# 200                  6
# 201                 31
# 202                 31
# 203                 21
#
# [204 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1B7X         B      3po1          B          1         6.361672
# 1       1C2B         A      1q83          A          1         0.907920
# 2       1C2B         A      5ehn          A          2         1.080483
# 3       1C2O         A      5ehn          A          1         1.080454
# 4       1C69         A      223l          A          2         0.420170
# ..       ...       ...       ...        ...        ...              ...
# 199     7X6S         A      5t2t          A          1         2.650229
# 200     7XF3         A      1xr9          A          1         0.853395
# 201     7YER         B      4ibe          A          1         1.469493
# 202     8PEA         A      5qap          B          1         3.203113
# 203     8PEA         A      5fas          A          2         3.075023
#
#                                             pocket_com  protein_id ligand  \
# 0    [-1.179043956920861, 3.6813078413359475, -4.61...         463    MKY
# 1    [8.411259284944135, 6.42240844842599, -1.09772...         445    TZ5
# 2    [10.875006421726553, 0.966960542765095, 13.718...         445    5NZ
# 3    [-4.17155269641972, 15.92296933888191, -6.0388...         445    5NZ
# 4    [-4.765451171875, -3.536183225631714, -14.4452...         443    BNZ
# ..                                                 ...         ...    ...
# 199  [12.149139881134033, 32.49655342102051, -18.84...         419    0N8
# 200  [-9.368043024658721, -0.3903163542579475, 11.4...         450    GOL
# 201  [-8.778923882378471, 0.5329759385850694, -20.7...         480    11Y
# 202  [-4.29671223039572, -11.24640649453753, 11.579...         447    AV7
# 203  [-10.900771909146696, -2.8350691305624474, -1....         447    5VR
#
#      ligand_atom_count
# 0                   20
# 1                   50
# 2                   49
# 3                   49
# 4                    6
# ..                 ...
# 199                 52
# 200                  6
# 201                 31
# 202                 31
# 203                 21
#
# [204 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     6NN6         K      4ek9          A          1     1.213021
# 1     6NN6         K      3qox          A          1     1.095194
# 2     6NN6         K      3sr4          A          1     1.123542
# 3     4MHN         A      4mhy          A          1     0.177633
#
#                                           pocket_com  protein_id ligand  \
# 0  [-5.929712613423665, 0.17129544858579282, 10.9...         501    EP4
# 1  [-5.929712613423665, 0.17129544858579282, 10.9...         501    SAH
# 2  [-5.929712613423665, 0.17129544858579282, 10.9...         501    TT8
# 3  [-7.138717155951958, 6.4866556254300205, 9.075...         502    PBD
#
#    ligand_atom_count
# 0                 21
# 1                 26
# 2                 27
# 3                 22
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A23         A      4tky          A          1     3.009529
# 1       1A23         A      4wey          B          2     2.069196
# 2       1AC1         A      4wey          B          1     1.572675
# 3       1ACV         A      4wey          B          1     1.581193
# 4       1AF2         A      1ctu          A          1     0.584431
# ..       ...       ...       ...        ...        ...          ...
# 205     8USX         A      4kfq          A          1     9.335638
# 206     8USX         A      1y20          A          2     2.592590
# 207     8UUE         A      1y20          A          1     2.615094
# 208     8VRS         A      1dmb          A          4     3.172956
# 209     8X34         A      4xmb          A          2     1.299385
#
#                                             pocket_com  protein_id ligand  \
# 0    [-12.130461747783766, 3.114823509427838, 0.934...         561    NaN
# 1    [3.370225857465695, -8.772779981295267, 9.2873...         561    EG6
# 2    [-2.1094470620155334, 12.66564745903015, 5.137...         561    EG6
# 3    [-2.043257123231888, 12.5133376121521, 5.03786...         561    EG6
# 4    [-7.325643161615243, 1.199986978841666, 6.4648...         581    ZEB
# ..                                                 ...         ...    ...
# 205  [-6.7070859112317045, 8.52809316900712, -18.62...         596    KFQ
# 206  [1.334150931135339, 7.279723589693136, -15.164...         596    1AC
# 207  [-5.436521003218476, 2.66330983202745, 4.86657...         595    1AC
# 208                                          [0, 0, 0]         531    GLC
# 209  [0.5814616863544171, 2.2761000119722805, 13.93...         570    41P
#
#      ligand_atom_count
# 0                    0
# 1                   22
# 2                   22
# 3                   22
# 4                   17
# ..                 ...
# 205                 15
# 206                  7
# 207                  7
# 208                 11
# 209                 70
#
# [210 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A23         A      4tky          A          1         3.009529
# 1       1A23         A      4wey          B          2         2.069196
# 2       1AC1         A      4wey          B          1         1.572675
# 3       1ACV         A      4wey          B          1         1.581193
# 4       1AF2         A      1ctu          A          1         0.584431
# ..       ...       ...       ...        ...        ...              ...
# 205     8USX         A      4kfq          A          1         9.335638
# 206     8USX         A      1y20          A          2         2.592590
# 207     8UUE         A      1y20          A          1         2.615094
# 208     8VRS         A      1dmb          A          4         3.172956
# 209     8X34         A      4xmb          A          2         1.299385
#
#                                             pocket_com  protein_id ligand  \
# 0    [-12.130461747783766, 3.114823509427838, 0.934...         561    NaN
# 1    [3.370225857465695, -8.772779981295267, 9.2873...         561    EG6
# 2    [-2.1094470620155334, 12.66564745903015, 5.137...         561    EG6
# 3    [-2.043257123231888, 12.5133376121521, 5.03786...         561    EG6
# 4    [-7.325643161615243, 1.199986978841666, 6.4648...         581    ZEB
# ..                                                 ...         ...    ...
# 205  [-6.7070859112317045, 8.52809316900712, -18.62...         596    KFQ
# 206  [1.334150931135339, 7.279723589693136, -15.164...         596    1AC
# 207  [-5.436521003218476, 2.66330983202745, 4.86657...         595    1AC
# 208                                          [0, 0, 0]         531    GLC
# 209  [0.5814616863544171, 2.2761000119722805, 13.93...         570    41P
#
#      ligand_atom_count
# 0                    0
# 1                   22
# 2                   22
# 3                   22
# 4                   17
# ..                 ...
# 205                 15
# 206                  7
# 207                  7
# 208                 11
# 209                 70
#
# [210 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     1A4J         A      1a4k          A          1     0.515849
# 1     3UQ3         A      3upv          A          1     1.403258
# 2     2GG4         A      2pqb          A          1     4.722650
# 3     2GG4         A      2pqc          A          1     4.743953
#
#                                           pocket_com  protein_id ligand  \
# 0  [-10.766914070777172, -4.497478077996452, -24....         601    FRA
# 1  [19.21295835971832, -17.101768445968627, -7.59...         602    NaN
# 2  [-6.390468373018153, -2.4874914281508502, -14....         603    GG9
# 3  [-6.390468373018153, -2.4874914281508502, -14....         603    RC1
#
#    ligand_atom_count
# 0                 31
# 1                  0
# 2                 28
# 3                 25
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A4J         A      1a4k          A          1     0.515849
# 1       1AK5         A      1pvn          A          1     1.080846
# 2       1AKM         A      1duv          G          1     1.448901
# 3       1AKZ         A      3fci          A          1     1.135150
# 4       1ALV         A      1alw          A          1     0.900199
# ..       ...       ...       ...        ...        ...          ...
# 180     8EMA         L      5a2k          H          2     1.976659
# 181     8IUO         A      4ucd          A          1     1.605626
# 182     8OP1         A      4ucd          A          1     1.631549
# 183     8OP2         A      4ucc          A          1     1.598219
# 184     9PAI         A      1a7c          A          2     6.484501
#
#                                             pocket_com  protein_id ligand  \
# 0    [-10.766914070777172, -4.497478077996452, -24....         601    FRA
# 1    [-1.818690380418157, 6.220432495975111, -9.679...         625    MZP
# 2    [-1.824917304806593, -10.790975431116616, 5.17...         685    PSQ
# 3    [-4.504822758853738, 0.8938618045167874, 5.747...         653    3FI
# 4    [4.1330914990655305, -4.827601991850754, -5.47...         666    ISA
# ..                                                 ...         ...    ...
# 180  [-4.738138299239309, 8.99759874845806, -28.040...         618    A2G
# 181  [35.65687221950955, 7.981548733181423, 1.90835...         691    M81
# 182  [-22.213890281883447, -19.757720225566143, -7....         691    M81
# 183  [-19.940194207268792, -16.564080521867083, 15....         691    ZKW
# 184  [0.2968330576940236, 10.984705327731099, -3.87...         645    NAG
#
#      ligand_atom_count
# 0                   31
# 1                   22
# 2                   17
# 3                   25
# 4                   13
# ..                 ...
# 180                 14
# 181                 26
# 182                 26
# 183                 26
# 184                 14
#
# [185 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A4J         A      1a4k          A          1         0.515849
# 1       1AK5         A      1pvn          A          1         1.080846
# 2       1AKM         A      1duv          G          1         1.448901
# 3       1AKZ         A      3fci          A          1         1.135150
# 4       1ALV         A      1alw          A          1         0.900199
# ..       ...       ...       ...        ...        ...              ...
# 180     8EMA         L      5a2k          H          2         1.976659
# 181     8IUO         A      4ucd          A          1         1.605626
# 182     8OP1         A      4ucd          A          1         1.631549
# 183     8OP2         A      4ucc          A          1         1.598219
# 184     9PAI         A      1a7c          A          2         6.484501
#
#                                             pocket_com  protein_id ligand  \
# 0    [-10.766914070777172, -4.497478077996452, -24....         601    FRA
# 1    [-1.818690380418157, 6.220432495975111, -9.679...         625    MZP
# 2    [-1.824917304806593, -10.790975431116616, 5.17...         685    PSQ
# 3    [-4.504822758853738, 0.8938618045167874, 5.747...         653    3FI
# 4    [4.1330914990655305, -4.827601991850754, -5.47...         666    ISA
# ..                                                 ...         ...    ...
# 180  [-4.738138299239309, 8.99759874845806, -28.040...         618    A2G
# 181  [35.65687221950955, 7.981548733181423, 1.90835...         691    M81
# 182  [-22.213890281883447, -19.757720225566143, -7....         691    M81
# 183  [-19.940194207268792, -16.564080521867083, 15....         691    ZKW
# 184  [0.2968330576940236, 10.984705327731099, -3.87...         645    NAG
#
#      ligand_atom_count
# 0                   31
# 1                   22
# 2                   17
# 3                   25
# 4                   13
# ..                 ...
# 180                 14
# 181                 26
# 182                 26
# 183                 26
# 184                 14
#
# [185 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     1A9O         A      1b8n          A          1     1.975077
# 1     1A9O         A      1b8o          A          1     2.004071
# 2     1A9O         A      1a9q          A          1     1.512738
# 3     1PBN         A      1b8n          A          1     2.164587
#
#                                           pocket_com  protein_id ligand  \
# 0  [13.304115469817521, 2.2159697833228202, 4.431...         701    IMG
# 1  [13.304115469817521, 2.2159697833228202, 4.431...         701    IMH
# 2  [13.304115469817521, 2.2159697833228202, 4.431...         701    HPA
# 3  [13.40969511692626, 2.2436010457198443, 4.3610...         701    IMG
#
#    ligand_atom_count
# 0                 20
# 1                 19
# 2                 10
# 3                 20
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A9O         A      1b8o          A          1     2.004071
# 1       1AF3         A      4qvx          A          1     2.475381
# 2       1APN         A      4pf5          A          1     2.889501
# 3       1APN         A      1jyc          A          2     1.821777
# 4       1BD3         A      1upf          A          1     0.677816
# ..       ...       ...       ...        ...        ...          ...
# 175     7U6G         A      5his          A          1     1.466979
# 176     7VDC         A      2ot1          A          2     1.508043
# 177     8D6J         A      3qx9          A          1     3.221108
# 178     8FYU         A      6nsv          A          1     4.405194
# 179     8OR2         F      5ufi          A          1     2.380019
#
#                                             pocket_com  protein_id ligand  \
# 0    [13.304115469817521, 2.2159697833228202, 4.431...         701    IMH
# 1    [2.169966130950855, 6.663480619826578, -0.8244...         716    3CQ
# 2    [2.2823074867850854, 3.3963747746066044, 13.44...         746    M3N
# 3    [-5.901083171367645, 7.630762108441057, 9.6976...         746    NaN
# 4    [13.506152346647905, 1.4250389225575146, -4.11...         711    URF
# ..                                                 ...         ...    ...
# 175  [4.859321608472226, 15.38879068573909, 2.39003...         765    60P
# 176  [-7.029869959904597, 15.481453528771034, -1.77...         741    N3P
# 177  [-7.873298673068776, -35.819279951207776, 8.95...         797    ATP
# 178  [-1.3207321119935889, 3.05175603063483, -5.754...         752    1PE
# 179  [6.881451586743335, -2.6442099973594115, -4.23...         750    8B1
#
#      ligand_atom_count
# 0                   19
# 1                   47
# 2                   18
# 3                    0
# 4                    9
# ..                 ...
# 175                 14
# 176                 25
# 177                 31
# 178                 38
# 179                 41
#
# [180 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A9O         A      1b8o          A          1         2.004071
# 1       1AF3         A      4qvx          A          1         2.475381
# 2       1APN         A      4pf5          A          1         2.889501
# 3       1APN         A      1jyc          A          2         1.821777
# 4       1BD3         A      1upf          A          1         0.677816
# ..       ...       ...       ...        ...        ...              ...
# 175     7U6G         A      5his          A          1         1.466979
# 176     7VDC         A      2ot1          A          2         1.508043
# 177     8D6J         A      3qx9          A          1         3.221108
# 178     8FYU         A      6nsv          A          1         4.405194
# 179     8OR2         F      5ufi          A          1         2.380019
#
#                                             pocket_com  protein_id ligand  \
# 0    [13.304115469817521, 2.2159697833228202, 4.431...         701    IMH
# 1    [2.169966130950855, 6.663480619826578, -0.8244...         716    3CQ
# 2    [2.2823074867850854, 3.3963747746066044, 13.44...         746    M3N
# 3    [-5.901083171367645, 7.630762108441057, 9.6976...         746    NaN
# 4    [13.506152346647905, 1.4250389225575146, -4.11...         711    URF
# ..                                                 ...         ...    ...
# 175  [4.859321608472226, 15.38879068573909, 2.39003...         765    60P
# 176  [-7.029869959904597, 15.481453528771034, -1.77...         741    N3P
# 177  [-7.873298673068776, -35.819279951207776, 8.95...         797    ATP
# 178  [-1.3207321119935889, 3.05175603063483, -5.754...         752    1PE
# 179  [6.881451586743335, -2.6442099973594115, -4.23...         750    8B1
#
#      ligand_atom_count
# 0                   19
# 1                   47
# 2                   18
# 3                    0
# 4                    9
# ..                 ...
# 175                 14
# 176                 25
# 177                 31
# 178                 38
# 179                 41
#
# [180 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     2K1B         A      4mn3          A          1     4.724605
# 1     2K1B         A      4x3t          A          1     3.803818
# 2     2K1B         A      4x3s          A          1     4.507771
# 3     2K1B         A      2l12          A          1     4.585727
#
#                                           pocket_com  protein_id ligand  \
# 0  [0.5139111094681057, -0.019106542200176258, -0...         801    P33
# 1  [0.5139111094681057, -0.019106542200176258, -0...         801    45E
# 2  [0.5139111094681057, -0.019106542200176258, -0...         801    CIT
# 3  [0.5139111094681057, -0.019106542200176258, -0...         801    M3L
#
#    ligand_atom_count
# 0                 13
# 1                 29
# 2                 13
# 3                 31
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A0N         B      1azg          B          1     2.512166
# 1       1AUG         A      3ro0          A          1     1.081541
# 2       1AVZ         C      1azg          B          1     1.353931
# 3       1AXC         A      1vyj          A          1     0.787483
# 4       1AXC         A      5mlw          A          2     1.663569
# ..       ...       ...       ...        ...        ...          ...
# 223     8BBK         A      4bvb          A          1     2.506474
# 224     8CN3         A      3rl8          B          1     4.170419
# 225     8CN3         B      3rl8          B          1     3.009594
# 226     8E84         A      1vyj          A          1     1.160198
# 227     8E84         A      5mlo          A          2     1.752221
#
#                                             pocket_com  protein_id ligand  \
# 0    [0.8095625839611091, 0.9148158431643306, -3.81...         835    NaN
# 1    [-7.338161667533543, 9.622080985359524, 3.1744...         854    TPT
# 2    [2.1519005468913486, 6.250575474330357, 1.3405...         835    NaN
# 3    [-3.835468545966192, -11.324269290364116, -6.9...         865    NaN
# 4    [-4.248839228606421, -0.09408883023853144, -9....         865    NaN
# ..                                                 ...         ...    ...
# 223  [6.982364701928559, -2.2960944560744005, -1.56...         891    AR6
# 224  [1.9703504337983972, 0.10669181627385757, 0.24...         820    NaN
# 225  [-3.546325554018435, -1.7451314679144516, -1.5...         820    NaN
# 226  [0.3197867945620888, -8.064175987243653, -12.1...         868    NaN
# 227  [6.421022055100422, 1.3120965471073074, -8.325...         868    NaN
#
#      ligand_atom_count
# 0                    0
# 1                   19
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 223                 36
# 224                  0
# 225                  0
# 226                  0
# 227                  0
#
# [228 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A0N         B      1azg          B          1         2.512166
# 1       1AUG         A      3ro0          A          1         1.081541
# 2       1AVZ         C      1azg          B          1         1.353931
# 3       1AXC         A      1vyj          A          1         0.787483
# 4       1AXC         A      5mlw          A          2         1.663569
# ..       ...       ...       ...        ...        ...              ...
# 223     8BBK         A      4bvb          A          1         2.506474
# 224     8CN3         A      3rl8          B          1         4.170419
# 225     8CN3         B      3rl8          B          1         3.009594
# 226     8E84         A      1vyj          A          1         1.160198
# 227     8E84         A      5mlo          A          2         1.752221
#
#                                             pocket_com  protein_id ligand  \
# 0    [0.8095625839611091, 0.9148158431643306, -3.81...         835    NaN
# 1    [-7.338161667533543, 9.622080985359524, 3.1744...         854    TPT
# 2    [2.1519005468913486, 6.250575474330357, 1.3405...         835    NaN
# 3    [-3.835468545966192, -11.324269290364116, -6.9...         865    NaN
# 4    [-4.248839228606421, -0.09408883023853144, -9....         865    NaN
# ..                                                 ...         ...    ...
# 223  [6.982364701928559, -2.2960944560744005, -1.56...         891    AR6
# 224  [1.9703504337983972, 0.10669181627385757, 0.24...         820    NaN
# 225  [-3.546325554018435, -1.7451314679144516, -1.5...         820    NaN
# 226  [0.3197867945620888, -8.064175987243653, -12.1...         868    NaN
# 227  [6.421022055100422, 1.3120965471073074, -8.325...         868    NaN
#
#      ligand_atom_count
# 0                    0
# 1                   19
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 223                 36
# 224                  0
# 225                  0
# 226                  0
# 227                  0
#
# [228 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     1JWF         A      1py1          A          1     1.465199
# 1     1JWF         A      3g2v          A          1     1.440753
# 2     1JWF         A      3g2w          A          1     1.539940
# 3     1JWF         A      1ujj          A          1     1.366245
#
#                                           pocket_com  protein_id ligand  \
# 0  [9.181232330905404, -1.7891966142472189, -6.64...         901    SEP
# 1  [9.181232330905404, -1.7891966142472189, -6.64...         901    SEP
# 2  [9.181232330905404, -1.7891966142472189, -6.64...         901    NaN
# 3  [9.181232330905404, -1.7891966142472189, -6.64...         901    NaN
#
#    ligand_atom_count
# 0                 10
# 1                 10
# 2                  0
# 3                  0
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1A5R         A      6k5t          A          1     2.834532
# 1       1ABO         A      1bbz          A          1     2.125875
# 2       1ADE         A      1qf4          A          1     2.644401
# 3       1ADE         A      1juy          A          2     2.536404
# 4       1ADE         A      1ch8          A          3     2.361848
# ..       ...       ...       ...        ...        ...          ...
# 196     8OHD         D      5hkh          A          1     1.189951
# 197     8SZX         A      4j77          A          2     0.887487
# 198     8T08         Q      4q1s          a          1     0.946850
# 199     8T08         Q      6g8m          a          2     0.974145
# 200     8T08         Q      3mg7          M          3     1.367064
#
#                                             pocket_com  protein_id ligand  \
# 0    [3.486114225434707, 2.148512696954721, -3.7013...         971    SEP
# 1    [2.4421743371708673, 3.766537131568198, -0.815...         930    NaN
# 2    [-2.070823000661982, -5.558456240959887, 8.815...         958    RPD
# 3    [-13.400681486669576, -0.0214688463031121, 4.4...         958    GDP
# 4    [4.692375113566716, 5.738586293326484, 2.64661...         958    GPX
# ..                                                 ...         ...    ...
# 196  [6.268601989746093, 5.007874298095703, -6.6756...         966    NaN
# 197                                          [0, 0, 0]         961    NaN
# 198  [-13.977343193390084, 0.3128686101181702, -3.4...         908    2YD
# 199  [7.657616355202415, 16.24172418767756, -7.3164...         908    EQE
# 200  [7.561254327947443, 20.183998801491477, -6.712...         908    L2T
#
#      ligand_atom_count
# 0                   14
# 1                    0
# 2                   30
# 3                   40
# 4                   31
# ..                 ...
# 196                  0
# 197                  0
# 198                 35
# 199                 32
# 200                 44
#
# [201 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1A5R         A      6k5t          A          1         2.834532
# 1       1ABO         A      1bbz          A          1         2.125875
# 2       1ADE         A      1qf4          A          1         2.644401
# 3       1ADE         A      1juy          A          2         2.536404
# 4       1ADE         A      1ch8          A          3         2.361848
# ..       ...       ...       ...        ...        ...              ...
# 196     8OHD         D      5hkh          A          1         1.189951
# 197     8SZX         A      4j77          A          2         0.887487
# 198     8T08         Q      4q1s          a          1         0.946850
# 199     8T08         Q      6g8m          a          2         0.974145
# 200     8T08         Q      3mg7          M          3         1.367064
#
#                                             pocket_com  protein_id ligand  \
# 0    [3.486114225434707, 2.148512696954721, -3.7013...         971    SEP
# 1    [2.4421743371708673, 3.766537131568198, -0.815...         930    NaN
# 2    [-2.070823000661982, -5.558456240959887, 8.815...         958    RPD
# 3    [-13.400681486669576, -0.0214688463031121, 4.4...         958    GDP
# 4    [4.692375113566716, 5.738586293326484, 2.64661...         958    GPX
# ..                                                 ...         ...    ...
# 196  [6.268601989746093, 5.007874298095703, -6.6756...         966    NaN
# 197                                          [0, 0, 0]         961    NaN
# 198  [-13.977343193390084, 0.3128686101181702, -3.4...         908    2YD
# 199  [7.657616355202415, 16.24172418767756, -7.3164...         908    EQE
# 200  [7.561254327947443, 20.183998801491477, -6.712...         908    L2T
#
#      ligand_atom_count
# 0                   14
# 1                    0
# 2                   30
# 3                   40
# 4                   31
# ..                 ...
# 196                  0
# 197                  0
# 198                 35
# 199                 32
# 200                 44
#
# [201 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     2YNS         A      4b8p          A          1     0.428375
# 1     2YNS         A      4b8o          A          2     1.108703
# 2     4B8J         A      2yns          A          2     0.866388
# 3     4B8J         A      4b8p          A          2     0.897938
#
#                                           pocket_com  protein_id ligand  \
# 0  [-10.110201640280044, -10.647049708767089, -0....        1001    NaN
# 1  [12.519116958441762, 14.953883950076351, -2.94...        1001    NaN
# 2  [0.8015602874755859, -5.587301120758057, -12.6...        1001    NaN
# 3  [0.8015602874755859, -5.587301120758057, -12.6...        1001    NaN
#
#    ligand_atom_count
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1AB9         B      2vgc          B          1     0.832420
# 1       1AB9         B      6cha          F          2     0.140833
# 2       1AB9         B      7gch          F          3     0.640058
# 3       1ABT         A      1jbd          A          1     5.266910
# 4       1ACB         E      2vgc          B          3     0.911678
# ..       ...       ...       ...        ...        ...          ...
# 199     7ZJV         B      6k5r          A          1     1.944118
# 200     8CN1         A      3rl7          A          1     1.194673
# 201     8D67         A      3rqw          B          3     1.878793
# 202     8SV1         A      3ns7          A          1     1.216939
# 203     8U7I         A      6k5r          A          1     1.951772
#
#                                             pocket_com  protein_id ligand  \
# 0    [5.2924670113457575, -6.407451483938429, 2.492...        1049    V35
# 1    [1.679495096206665, -5.626993268728256, -1.416...        1049    PBA
# 2    [17.745880829660518, 2.242274372201217, 7.1328...        1049    LPF
# ...
# 158  [-1.909169224330357, 3.662701416015625, 12.099...        1738    CY9
# 159                                          [0, 0, 0]        1726    HUJ
# 160  [8.001927439371745, -0.2666637897491455, -0.73...        1708    7L9
# 161  [5.236172765493393, -8.09801564613978, 0.55097...        1708    7L9
#
#      ligand_atom_count
# 0                    0
# 1                    0
# 2                   34
# 3                   28
# 4                   21
# ..                 ...
# 157                 14
# 158                 37
# 159                 33
# 160                 21
# 161                 21
#
# [162 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     3L8I         A      3rqg          C          1     1.061499
# 1     4GEH         A      3rqg          C          1     1.033597
# 2     3L8J         A      3rqg          C          1     1.191183
# 3     7W9V         K      5lpm          A          1     0.966058
#
#                                           pocket_com  protein_id ligand  \
# 0  [-2.9388932783013852, 7.16937894106742, 9.8370...        1801    NaN
# 1  [2.0833486693246024, -3.195815862928118, 12.84...        1801    NaN
# 2  [-10.254655381907588, -0.1357624219811481, 5.7...        1801    NaN
# 3  [-5.361742548195712, 5.275661928107939, 35.855...        1803    71Y
#
#    ligand_atom_count
# 0                  0
# 1                  0
# 2                  0
# 3                 49
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1AK1         A      2q2n          A          1     1.289043
# 1       1B6F         A      4qip          A          1     3.087945
# 2       1B9K         A      3hs8          A          1     1.038637
# 3       1BTV         A      4qip          A          1     1.425305
# 4       1BVN         P      1pig          A          1     1.260954
# ..       ...       ...       ...        ...        ...          ...
# 175     8HTA         A      4oru          A          1     3.359730
# 176     8I9M         B      2l7u          A          1     6.646954
# 177     8JF7         D      2rc9          A          1     8.880864
# 178     8T2M         A      3d32          B          1     3.166690
# 179     8W8Q         C      5zk3          A          1    12.577912
#
#                                             pocket_com  protein_id ligand  \
# 0    [-17.2828115366273, -2.395466788340423, -8.576...        1899    H01
# 1    [2.2444710978755245, -12.135626941257053, 0.96...        1840    SDS
# 2    [1.769306551416715, -12.676116041342418, 8.990...        1859    NaN
# 3    [-3.0248788019567727, -10.554389692306518, 4.9...        1840    SDS
# 4    [13.252284148304733, -3.6558175726035205, 12.5...        1890    BGC
# ..                                                 ...         ...    ...
# 175  [1.0218793864907616, -0.3580299959346064, -6.7...        1831    PEU
# 176  [-0.6689648098415799, -2.3362299601236978, -5....        1870    KPI
# 177  [-45.669775390625, 13.611015129089356, -15.585...        1810    1AC
# 178  [1.339860289142682, -7.6854409999572315, 2.343...        1804    NaN
# 179  [-4.886885989796031, -16.939643079584297, 2.82...        1852    QNB
#
#      ligand_atom_count
# 0                   46
# 1                   17
# 2                    0
# 3                   17
# 4                   12
# ..                 ...
# 175                 76
# 176                 29
# 177                  7
# 178                  0
# 179                 25
#
# [180 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1AK1         A      2q2n          A          1         1.289043
# 1       1B6F         A      4qip          A          1         3.087945
# 2       1B9K         A      3hs8          A          1         1.038637
# 3       1BTV         A      4qip          A          1         1.425305
# 4       1BVN         P      1pig          A          1         1.260954
# ..       ...       ...       ...        ...        ...              ...
# 175     8HTA         A      4oru          A          1         3.359730
# 176     8I9M         B      2l7u          A          1         6.646954
# 177     8JF7         D      2rc9          A          1         8.880864
# 178     8T2M         A      3d32          B          1         3.166690
# 179     8W8Q         C      5zk3          A          1        12.577912
#
#                                             pocket_com  protein_id ligand  \
# 0    [-17.2828115366273, -2.395466788340423, -8.576...        1899    H01
# 1    [2.2444710978755245, -12.135626941257053, 0.96...        1840    SDS
# 2    [1.769306551416715, -12.676116041342418, 8.990...        1859    NaN
# 3    [-3.0248788019567727, -10.554389692306518, 4.9...        1840    SDS
# 4    [13.252284148304733, -3.6558175726035205, 12.5...        1890    BGC
# ..                                                 ...         ...    ...
# 175  [1.0218793864907616, -0.3580299959346064, -6.7...        1831    PEU
# 176  [-0.6689648098415799, -2.3362299601236978, -5....        1870    KPI
# 177  [-45.669775390625, 13.611015129089356, -15.585...        1810    1AC
# 178  [1.339860289142682, -7.6854409999572315, 2.343...        1804    NaN
# 179  [-4.886885989796031, -16.939643079584297, 2.82...        1852    QNB
#
#      ligand_atom_count
# 0                   46
# 1                   17
# 2                    0
# 3                   17
# 4                   12
# ..                 ...
# 175                 76
# 176                 29
# 177                  7
# 178                  0
# 179                 25
#
# [180 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     5XAE         A      2n9x          A          1     4.527283
# 1     5XAE         A      5gmv          B          1     2.151399
# 2     1J8F         A      5mar          A          1     3.105508
# 3     1J8F         A      5mat          A          1     2.751037
#
#                                           pocket_com  protein_id ligand  \
# 0  [6.598139365817451, 0.6763492540548776, 0.9800...        1901    NaN
# 1  [6.598139365817451, 0.6763492540548776, 0.9800...        1901    SEP
# 2  [-6.222133569605959, -9.066393933431533, -2.29...        1902    AR6
# 3  [-6.222133569605959, -9.066393933431533, -2.29...        1902    7KJ
#
#    ligand_atom_count
# 0                  0
# 1                 10
# 2                 56
# 3                 65
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1AMH         A      1bra          A          1     1.505020
# 1       1B73         A      1b74          A          1     0.407218
# 2       1CTX         A      1lxh          A          1     8.142664
# 3       1D7F         A      1ukt          A          1     0.593185
# 4       1EVH         A      4my6          A          1     0.808300
# ..       ...       ...       ...        ...        ...          ...
# 139     8D3B         A      4wym          F          1     5.323141
# 140     8DYX         A      6axk          A          1     1.084762
# 141     8QEN         A      3pa8          A          1     6.749144
# 142     8RBX         q      2ie4          C          1     1.044297
# 143     8UWB         C      2ie4          C          1     0.991875
#
#                                             pocket_com  protein_id ligand  \
# 0    [-1.4136270114353724, 4.110800786649588, 9.014...        1958    BEN
# 1    [3.4639774806915766, 5.147538684663319, -3.764...        1926    DGN
# 2    [1.1615905712048213, 0.662793348232905, -3.182...        1927    NaN
# 3    [11.44678677452935, 6.6136190626356335, 15.821...        1971    ACI
# 4    [-4.276242749257521, 5.133145223964345, 2.9506...        1939    3VH
# ..                                                 ...         ...    ...
# 139  [7.723491900497013, -7.174743864271376, 9.8875...        1982    NaN
# 140  [-0.5117215757016782, 9.369109259711372, 4.191...        1975    MES
# 141  [2.0409279563210228, 25.504052179509944, 57.35...        1989    IHP
# 142  [-0.052595998726639094, 11.908955592735142, 5....        1940    OKA
# 143  [2.136475302956321, 11.122378436001865, 12.311...        1940    OKA
#
#      ligand_atom_count
# 0                    9
# 1                   10
# 2                    0
# 3                   12
# 4                   48
# ..                 ...
# 139                  0
# 140                 25
# 141                 36
# 142                 57
# 143                 57
#
# [144 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1AMH         A      1bra          A          1         1.505020
# 1       1B73         A      1b74          A          1         0.407218
# 2       1CTX         A      1lxh          A          1         8.142664
# 3       1D7F         A      1ukt          A          1         0.593185
# 4       1EVH         A      4my6          A          1         0.808300
# ..       ...       ...       ...        ...        ...              ...
# 139     8D3B         A      4wym          F          1         5.323141
# 140     8DYX         A      6axk          A          1         1.084762
# 141     8QEN         A      3pa8          A          1         6.749144
# 142     8RBX         q      2ie4          C          1         1.044297
# 143     8UWB         C      2ie4          C          1         0.991875
#
#                                             pocket_com  protein_id ligand  \
# 0    [-1.4136270114353724, 4.110800786649588, 9.014...        1958    BEN
# 1    [3.4639774806915766, 5.147538684663319, -3.764...        1926    DGN
# 2    [1.1615905712048213, 0.662793348232905, -3.182...        1927    NaN
# 3    [11.44678677452935, 6.6136190626356335, 15.821...        1971    ACI
# 4    [-4.276242749257521, 5.133145223964345, 2.9506...        1939    3VH
# ..                                                 ...         ...    ...
# 139  [7.723491900497013, -7.174743864271376, 9.8875...        1982    NaN
# 140  [-0.5117215757016782, 9.369109259711372, 4.191...        1975    MES
# 141  [2.0409279563210228, 25.504052179509944, 57.35...        1989    IHP
# 142  [-0.052595998726639094, 11.908955592735142, 5....        1940    OKA
# 143  [2.136475302956321, 11.122378436001865, 12.311...        1940    OKA
#
#      ligand_atom_count
# 0                    9
# 1                   10
# 2                    0
# 3                   12
# 4                   48
# ..                 ...
# 139                  0
# 140                 25
# 141                 36
# 142                 57
# 143                 57
#
# [144 rows x 10 columns]
# df :
#   apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0     6ER2         A      6er4          A          1     1.811657
# 1     5VAU         A      2o22          A          1     3.581819
# 2     1GJH         A      2o22          A          1     1.724588
# 3     6E8H         A      6e8m          A          1     1.041613
#
#                                           pocket_com  protein_id ligand  \
# 0  [4.912237102106998, -1.9072962083314595, 6.902...        2001    SIA
# 1  [-0.11656741087868709, -5.175600046679477, -7....        2002    LIU
# 2  [10.023251170097891, 0.7142462730407715, -2.25...        2003    LIU
# 3  [1.239945488591348, -3.9362792430385465, 2.273...        2004    PTR
#
#    ligand_atom_count
# 0                 20
# 1                 77
# 2                 77
# 3                 16
# result :
#     apo_name apo_chain holo_name holo_chain  pocket_id  pocket_rmsd  \
# 0       1ANT         I      1e03          L          1     4.276388
# 1       1B10         A      2lh8          A          1     2.022344
# 2       1C3P         A      1c3r          B          1     0.924084
# 3       1CLW         A      3th0          A          1     0.617453
# 4       1D2K         A      1ll4          A          1     0.686273
# ..       ...       ...       ...        ...        ...          ...
# 97      7M4R         A      4uu5          A          1     1.529424
# 98      7N8J         A      4wv6          A          1     1.492631
# 99      7PCV         A      2lk1          A          1     1.905866
# 100     7QCS         A      4uu5          A          1          inf
# 101     8TVR         A      3th0          A          1          inf
#
#                                             pocket_com  protein_id ligand  \
# 0    [-15.349651789493699, 1.6569644701566628, 8.90...        2044    Z9L
# 1    [-10.505668436296475, 5.024363289193179, 5.447...        2046    VIB
# 2    [-14.702224558049982, -5.979061349645837, -6.0...        2041    TSN
# 3    [-3.47984294212366, -14.674043217137408, -1.89...        2039    RAM
# 4    [-8.37217488008387, 7.953917250913732, -2.7608...        2043    AMI
# ..                                                 ...         ...    ...
# 97   [-9.704705238342285, 25.67856788635254, -2.167...        2017    PUN
# 98   [15.848571719545307, 8.974626541137695, 4.1582...        2054    EDO
# 99   [4.069018511014564, 17.28296090954932, -0.8927...        2009    AQN
# 100  [-3.633496940135956, 7.645703136920929, -2.275...        2017    PUN
# 101                                          [0, 0, 0]        2039    RAM
#
#      ligand_atom_count
# 0                   25
# 1                   35
# 2                   22
# 3                   11
# 4                   15
# ..                 ...
# 97                  50
# 98                  10
# 99                  27
# 100                 50
# 101                 11
#
# [102 rows x 10 columns]
#     apo_name apo_chain holo_name holo_chain  pocket_id  max_pocket_rmsd  \
# 0       1ANT         I      1e03          L          1         4.276388
# 1       1B10         A      2lh8          A          1         2.022344
# 2       1C3P         A      1c3r          B          1         0.924084
# 3       1CLW         A      3th0          A          1         0.617453
# 4       1D2K         A      1ll4          A          1         0.686273
# ..       ...       ...       ...        ...        ...              ...
# 97      7M4R         A      4uu5          A          1         1.529424
# 98      7N8J         A      4wv6          A          1         1.492631
# 99      7PCV         A      2lk1          A          1         1.905866
# 100     7QCS         A      4uu5          A          1              inf
# 101     8TVR         A      3th0          A          1              inf
#
#                                             pocket_com  protein_id ligand  \
# 0    [-15.349651789493699, 1.6569644701566628, 8.90...        2044    Z9L
# 1    [-10.505668436296475, 5.024363289193179, 5.447...        2046    VIB
# 2    [-14.702224558049982, -5.979061349645837, -6.0...        2041    TSN
# 3    [-3.47984294212366, -14.674043217137408, -1.89...        2039    RAM
# 4    [-8.37217488008387, 7.953917250913732, -2.7608...        2043    AMI
# ..                                                 ...         ...    ...
# 97   [-9.704705238342285, 25.67856788635254, -2.167...        2017    PUN
# 98   [15.848571719545307, 8.974626541137695, 4.1582...        2054    EDO
# 99   [4.069018511014564, 17.28296090954932, -0.8927...        2009    AQN
# 100  [-3.633496940135956, 7.645703136920929, -2.275...        2017    PUN
# 101                                          [0, 0, 0]        2039    RAM
#
#      ligand_atom_count
# 0                   25
# 1                   35
# 2                   22
# 3                   11
# 4                   15
# ..                 ...
# 97                  50
# 98                  10
# 99                  27
# 100                 50
# 101                 11
#
# [102 rows x 10 columns]
